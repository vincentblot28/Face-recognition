# %%
import zipfile
import os
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from PIL import Image
from matplotlib.pyplot import imshow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model, load_model
from keras.layers.core import Dense, Dropout, Activation,Flatten
from tensorflow.keras.layers import Input, concatenate, Dense, Flatten, Activation, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LambdaCallback
from keras import optimizers
from keras.utils import np_utils
# %matplotlib inline

from google.colab import drive, files
drive.mount('/content/gdrive',force_remount=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Using TensorFlow backend.

# %% [markdown]
# ## Unzipping the file with the images

# %%
import zipfile
with zipfile.ZipFile('/content/gdrive/My Drive/Big Data/Projet/celeba-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/img/')

# %% [markdown]
# # Resize images

# %%
image = Image.open('/content/img/img_align_celeba/img_align_celeba/000001.jpg')
new_image = image.resize((64, 64))
plt.imshow(new_image)

# %% [markdown]
# # Création de la base de données

# %%
samp = pickle.load(open ('/content/gdrive/My Drive/Big Data/Projet/Listes sample/Straight_Hair.pkl', 'rb'))

# %%
path = '/content/img/img_align_celeba/img_align_celeba/'
target = []
data = np.zeros((len(samp), 64, 64, 3)) #dimension of the images
count = 0
for file in os.listdir(path) :
  if file in samp :
    image = Image.open(path + file)
    image = image.resize((64, 64))
    data[count] = np.array(image)
    target.append(file)
    if count%1000 == 0 :
      print(count)
    count += 1
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000

# %%
all_attributes = pd.read_csv('/content/img/list_attr_celeba.csv')
straight = all_attributes[['image_id','Straight_Hair']]
straight = straight.loc[straight[straight['image_id'].isin(target) == True].index]
straight = straight.set_index('image_id')
straight = straight.loc[target]
straight.head()
# Out:
#             Straight_Hair
# image_id
# 048657.jpg              1
# 154771.jpg              1
# 101896.jpg             -1
# 022724.jpg              1
# 170648.jpg             -1

# %%
len(straight)
# Out:
# 20000

# %%
data.shape
# Out:
# (20000, 64, 64, 3)

# %% [markdown]
# # Creation of the train and test sets

# %%
target = np.array(straight.Straight_Hair)
target[target==-1] = 0

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.2)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (16000, 64, 64, 3) (16000,)

# %%
np.array(straight.Straight_Hair)[1:100].shape
# Out:
# (99,)

# %%
y_train.shape
# Out:
# (16000,)

# %% [markdown]
# # Creation of the NN

# %%
conv_net = Sequential()

# convolution layer 1
conv_net.add(Conv2D(64, (3, 3), activation = 'relu', input_shape = (64, 64, 3)))
conv_net.add(MaxPooling2D(pool_size = (2, 2)))
conv_net.add(Dropout(0.2))

print(conv_net.output.shape)

# convolution layer 2
conv_net.add(Conv2D(128, (3, 3), activation = 'relu'))
conv_net.add(MaxPooling2D(pool_size = (2, 2)))
conv_net.add(Dropout(0.2))

# convolution layer 3
conv_net.add(Conv2D(256, (3, 3), activation = 'relu'))
conv_net.add(MaxPooling2D(pool_size = (2, 2)))
conv_net.add(Dropout(0.2))

# convolution layer 3
conv_net.add(Conv2D(512, (3, 3), activation = 'relu'))
conv_net.add(MaxPooling2D(pool_size = (2, 2)))
conv_net.add(Dropout(0.2))

print(conv_net.output.shape)

# fully connected
conv_net.add(Flatten())
conv_net.add(Dense(2048, activation = 'relu'))
conv_net.add(Dropout(0.2))
conv_net.add(Dense(1024, activation = 'relu'))
conv_net.add(Dropout(0.2))
conv_net.add(Dense(512, activation = 'relu'))
conv_net.add(Dropout(0.2))
conv_net.add(Dense(128, activation = 'relu'))
conv_net.add(Dropout(0.2))
conv_net.add(Dense(1, activation = 'sigmoid'))

conv_net.compile(loss = 'binary_crossentropy', optimizer = 'adam', 
                 metrics = ['accuracy'])
# Out:
# (None, 31, 31, 64)
# (None, 2, 2, 512)

# %% [markdown]
# ## callbacks to save the best model

# %%
reduce_lr = ReduceLROnPlateau(monitor = 'loss', factor = 0.2,
                              patience = 1, min_lr = 0.001)

# Path where we will save our model
filepath = "/content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5" 
checkpoint = ModelCheckpoint(filepath, monitor = 'val_accuracy',
                             verbose = 1, save_best_only = True,
                             mode = 'max')
callbacks = [checkpoint, reduce_lr]

# %%
conv_net.fit(X_train, y_train, batch_size = 256, epochs = 100, 
             validation_data = (X_test, y_test), callbacks = callbacks)
# Out:
# Epoch 1/100
# 63/63 [==============================] - ETA: 0s - loss: 3.8342 - accuracy: 0.5086
# Epoch 00001: val_accuracy improved from -inf to 0.51925, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
# 63/63 [==============================] - 4s 66ms/step - loss: 3.8342 - accuracy: 0.5086 - val_loss: 0.6929 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 2/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5192
# Epoch 00002: val_accuracy improved from 0.51925 to 0.55925, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
# 63/63 [==============================] - 3s 55ms/step - loss: 0.6927 - accuracy: 0.5192 - val_loss: 0.6912 - val_accuracy: 0.5592 - lr: 0.0010
# Epoch 3/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.5305
# Epoch 00003: val_accuracy did not improve from 0.55925
# 63/63 [==============================] - 3s 49ms/step - loss: 0.6909 - accuracy: 0.5305 - val_loss: 0.6882 - val_accuracy: 0.5447 - lr: 0.0010
# Epoch 4/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6867 - accuracy: 0.5530
# Epoch 00004: val_accuracy did not improve from 0.55925
# 63/63 [==============================] - 3s 49ms/step - loss: 0.6867 - accuracy: 0.5530 - val_loss: 0.6853 - val_accuracy: 0.5325 - lr: 0.0010
# Epoch 5/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.5692
# Epoch 00005: val_accuracy improved from 0.55925 to 0.56975, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
# 63/63 [==============================] - 4s 63ms/step - loss: 0.6792 - accuracy: 0.5692 - val_loss: 0.6761 - val_accuracy: 0.5698 - lr: 0.0010
# Epoch 6/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6806 - accuracy: 0.5692
# Epoch 00006: val_accuracy did not improve from 0.56975
# 63/63 [==============================] - 3s 49ms/step - loss: 0.6806 - accuracy: 0.5692 - val_loss: 0.6896 - val_accuracy: 0.5330 - lr: 0.0010
# Epoch 7/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6734 - accuracy: 0.5822
# Epoch 00007: val_accuracy improved from 0.56975 to 0.59375, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
# 63/63 [==============================] - 3s 55ms/step - loss: 0.6734 - accuracy: 0.5822 - val_loss: 0.6774 - val_accuracy: 0.5938 - lr: 0.0010
# Epoch 8/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6695 - accuracy: 0.5881
# Epoch 00008: val_accuracy did not improve from 0.59375
# 63/63 [==============================] - 3s 49ms/step - loss: 0.6695 - accuracy: 0.5881 - val_loss: 0.6745 - val_accuracy: 0.5800 - lr: 0.0010
# Epoch 9/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6567 - accuracy: 0.6131
# Epoch 00009: val_accuracy improved from 0.59375 to 0.60150, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
# 63/63 [==============================] - 3s 55ms/step - loss: 0.6567 - accuracy: 0.6131 - val_loss: 0.6547 - val_accuracy: 0.6015 - lr: 0.0010
# Epoch 10/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6451 - accuracy: 0.6313
# Epoch 00010: val_accuracy improved from 0.60150 to 0.63975, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
# 63/63 [==============================] - 3s 55ms/step - loss: 0.6451 - accuracy: 0.6313 - val_loss: 0.6344 - val_accuracy: 0.6398 - lr: 0.0010
# Epoch 11/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6349 - accuracy: 0.6432
# Epoch 00011: val_accuracy improved from 0.63975 to 0.65425, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
# 63/63 [==============================] - 3s 54ms/step - loss: 0.6349 - accuracy: 0.6432 - val_loss: 0.6238 - val_accuracy: 0.6543 - lr: 0.0010
# Epoch 12/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6300 - accuracy: 0.6476
# Epoch 00012: val_accuracy did not improve from 0.65425
# 63/63 [==============================] - 3s 49ms/step - loss: 0.6300 - accuracy: 0.6476 - val_loss: 0.6335 - val_accuracy: 0.6478 - lr: 0.0010
# Epoch 13/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6200 - accuracy: 0.6564
# Epoch 00013: val_accuracy did not improve from 0.65425
# 63/63 [==============================] - 3s 49ms/step - loss: 0.6200 - accuracy: 0.6564 - val_loss: 0.6261 - val_accuracy: 0.6330 - lr: 0.0010
# Epoch 14/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6122 - accuracy: 0.6674
# Epoch 00014: val_accuracy improved from 0.65425 to 0.65525, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
# 63/63 [==============================] - 3s 55ms/step - loss: 0.6122 - accuracy: 0.6674 - val_loss: 0.6143 - val_accuracy: 0.6553 - lr: 0.0010
# Epoch 15/100
# 63/63 [==============================] - ETA: 0s - loss: 0.6011 - accuracy: 0.6751
# Epoch 00015: val_accuracy improved from 0.65525 to 0.66575, saving model to /content/gdrive/My Drive/Big Data/models/Straight_Hair.hdf5
