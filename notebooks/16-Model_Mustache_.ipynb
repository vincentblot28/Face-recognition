# %%
import zipfile
import os
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from google.colab import drive, files
from PIL import Image
from matplotlib.pyplot import imshow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.image import array_to_img
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation,Flatten
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LambdaCallback
from keras.utils import np_utils
# %matplotlib inline

drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Unzipping the file with the images

# %%
with zipfile.ZipFile('/content/gdrive/My Drive/Big Data/Projet/celeba-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/img/')

# %% [markdown]
# # Création de la base de données

# %%
samp = pickle.load(open('/content/gdrive/My Drive/Big Data/Projet/Listes sample/Mustache.pkl', 'rb'))

# %%
path = '/content/img/img_align_celeba/img_align_celeba/'
target = []
data = np.zeros((len(samp), 64, 64, 3)) #dimension of the images
count = 0
for file in os.listdir(path) :
  if file in samp :
    image = Image.open(path + file)
    image = image.resize((64, 64))
    data[count] = np.array(image)
    target.append(file)
    count += 1

# %%
data.shape

# %%
all_attributes = pd.read_csv('/content/img/list_attr_celeba.csv')
mustache = all_attributes[['image_id','Mustache']]
mustache = mustache.loc[mustache[mustache['image_id'].isin(target) == True].index]
mustache = mustache.set_index('image_id')
mustache = mustache.loc[target]
mustache.head()
# Out:
#             Mustache
# image_id
# 145452.jpg         1
# 060196.jpg        -1
# 007271.jpg        -1
# 025695.jpg        -1
# 001372.jpg         1

# %% [markdown]
# # Creation of the train and test sets

# %%
y = np.array(mustache.Mustache)
y[y == -1] = 0

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size = 0.2)

# %%
print(y_train.shape, X_train.shape)
# Out:
# (14733,) (14733, 64, 64, 3)

# %% [markdown]
# # Creation of the NN

# %%
Mustache_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 62, 62, 64)        1792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 18, 18, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 477,825
# Trainable params: 477,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
conv_net = Sequential()

# convolution layer 1
conv_net.add(Conv2D(64, (3, 3), activation = 'relu', input_shape = (64, 64, 3)))
conv_net.add(MaxPooling2D(pool_size=(3, 3)))

# convolution layer 2
conv_net.add(Conv2D(128, (3, 3), activation = 'relu'))
conv_net.add(MaxPooling2D(pool_size = (3, 3)))

# convolution layer 3
conv_net.add(Conv2D(256, (3, 3), activation = 'relu'))
conv_net.add(MaxPooling2D(pool_size = (3, 3)))


conv_net.add(Flatten())
conv_net.add(Dense(256, activation = 'relu'))
conv_net.add(Dropout(0.3))
conv_net.add(Dense(128, activation = 'relu'))
conv_net.add(Dense(64, activation = 'relu'))
conv_net.add(Dense(1, activation = 'sigmoid'))

conv_net.compile(loss = 'binary_crossentropy', optimizer = 'adam', 
                 metrics = ['accuracy'])

# %% [markdown]
# ## callbacks to save the best model

# %%
reduce_lr = ReduceLROnPlateau(monitor = 'loss', factor = 0.2,
                              patience = 1, min_lr = 0.001)

# Path where we will save our model
filepath = "/content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5" 
checkpoint = ModelCheckpoint(filepath, monitor = 'val_accuracy',
                             verbose = 1, save_best_only = True,
                             mode = 'max')
callbacks = [checkpoint, reduce_lr]

# %%
history = conv_net.fit(X_train, y_train, batch_size = 128, epochs = 30, 
                       validation_data = (X_test, y_test), callbacks = callbacks) 
#total of 30 epochs
# Out:
# Epoch 1/30
# 116/116 [==============================] - ETA: 0s - loss: 1.0375 - accuracy: 0.5740
# Epoch 00001: val_accuracy improved from -inf to 0.64685, saving model to /content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5
# 116/116 [==============================] - 60s 521ms/step - loss: 1.0375 - accuracy: 0.5740 - val_loss: 0.6070 - val_accuracy: 0.6469 - lr: 0.0010
# Epoch 2/30
# 116/116 [==============================] - ETA: 0s - loss: 0.5081 - accuracy: 0.7361
# Epoch 00002: val_accuracy improved from 0.64685 to 0.77307, saving model to /content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5
# 116/116 [==============================] - 56s 486ms/step - loss: 0.5081 - accuracy: 0.7361 - val_loss: 0.4884 - val_accuracy: 0.7731 - lr: 0.0010
# Epoch 3/30
# 116/116 [==============================] - ETA: 0s - loss: 0.4065 - accuracy: 0.8067
# Epoch 00003: val_accuracy improved from 0.77307 to 0.79587, saving model to /content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5
# 116/116 [==============================] - 57s 490ms/step - loss: 0.4065 - accuracy: 0.8067 - val_loss: 0.4300 - val_accuracy: 0.7959 - lr: 0.0010
# Epoch 4/30
# 116/116 [==============================] - ETA: 0s - loss: 0.3780 - accuracy: 0.8245
# Epoch 00004: val_accuracy improved from 0.79587 to 0.84663, saving model to /content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5
# 116/116 [==============================] - 57s 490ms/step - loss: 0.3780 - accuracy: 0.8245 - val_loss: 0.3554 - val_accuracy: 0.8466 - lr: 0.0010
# Epoch 5/30
# 116/116 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.8512
# Epoch 00005: val_accuracy did not improve from 0.84663
# 116/116 [==============================] - 57s 489ms/step - loss: 0.3378 - accuracy: 0.8512 - val_loss: 0.3422 - val_accuracy: 0.8464 - lr: 0.0010
# Epoch 6/30
# 116/116 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.8647
# Epoch 00006: val_accuracy did not improve from 0.84663
# 116/116 [==============================] - 56s 486ms/step - loss: 0.3161 - accuracy: 0.8647 - val_loss: 0.3864 - val_accuracy: 0.8325 - lr: 0.0010
# Epoch 7/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8725
# Epoch 00007: val_accuracy did not improve from 0.84663
# 116/116 [==============================] - 55s 478ms/step - loss: 0.2985 - accuracy: 0.8725 - val_loss: 0.3722 - val_accuracy: 0.8271 - lr: 0.0010
# Epoch 8/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2857 - accuracy: 0.8761
# Epoch 00008: val_accuracy improved from 0.84663 to 0.85342, saving model to /content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5
# 116/116 [==============================] - 57s 490ms/step - loss: 0.2857 - accuracy: 0.8761 - val_loss: 0.3415 - val_accuracy: 0.8534 - lr: 0.0010
# Epoch 9/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2686 - accuracy: 0.8866
# Epoch 00009: val_accuracy did not improve from 0.85342
# 116/116 [==============================] - 56s 485ms/step - loss: 0.2686 - accuracy: 0.8866 - val_loss: 0.3617 - val_accuracy: 0.8504 - lr: 0.0010
# Epoch 10/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.8926
# Epoch 00010: val_accuracy improved from 0.85342 to 0.86129, saving model to /content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5
# 116/116 [==============================] - 57s 494ms/step - loss: 0.2625 - accuracy: 0.8926 - val_loss: 0.3325 - val_accuracy: 0.8613 - lr: 0.0010
# Epoch 11/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2488 - accuracy: 0.8978
# Epoch 00011: val_accuracy did not improve from 0.86129
# 116/116 [==============================] - 57s 494ms/step - loss: 0.2488 - accuracy: 0.8978 - val_loss: 0.3386 - val_accuracy: 0.8564 - lr: 0.0010
# Epoch 12/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.8989
# Epoch 00012: val_accuracy improved from 0.86129 to 0.87731, saving model to /content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5
# 116/116 [==============================] - 57s 487ms/step - loss: 0.2465 - accuracy: 0.8989 - val_loss: 0.3025 - val_accuracy: 0.8773 - lr: 0.0010
# Epoch 13/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9035
# Epoch 00013: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 483ms/step - loss: 0.2329 - accuracy: 0.9035 - val_loss: 0.3284 - val_accuracy: 0.8654 - lr: 0.0010
# Epoch 14/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9109
# Epoch 00014: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 484ms/step - loss: 0.2214 - accuracy: 0.9109 - val_loss: 0.3082 - val_accuracy: 0.8757 - lr: 0.0010
# Epoch 15/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9163
# Epoch 00015: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 485ms/step - loss: 0.2125 - accuracy: 0.9163 - val_loss: 0.3341 - val_accuracy: 0.8624 - lr: 0.0010
# Epoch 16/30
# 116/116 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9184
# Epoch 00016: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 59s 506ms/step - loss: 0.2059 - accuracy: 0.9184 - val_loss: 0.3991 - val_accuracy: 0.8548 - lr: 0.0010
# Epoch 17/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9268
# Epoch 00017: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 55s 476ms/step - loss: 0.1913 - accuracy: 0.9268 - val_loss: 0.3348 - val_accuracy: 0.8678 - lr: 0.0010
# Epoch 18/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1793 - accuracy: 0.9328
# Epoch 00018: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 483ms/step - loss: 0.1793 - accuracy: 0.9328 - val_loss: 0.3837 - val_accuracy: 0.8637 - lr: 0.0010
# Epoch 19/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1738 - accuracy: 0.9344
# Epoch 00019: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 482ms/step - loss: 0.1738 - accuracy: 0.9344 - val_loss: 0.3735 - val_accuracy: 0.8662 - lr: 0.0010
# Epoch 20/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9350
# Epoch 00020: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 57s 488ms/step - loss: 0.1672 - accuracy: 0.9350 - val_loss: 0.4097 - val_accuracy: 0.8700 - lr: 0.0010
# Epoch 21/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9352
# Epoch 00021: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 57s 489ms/step - loss: 0.1668 - accuracy: 0.9352 - val_loss: 0.4108 - val_accuracy: 0.8659 - lr: 0.0010
# Epoch 22/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9441
# Epoch 00022: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 57s 494ms/step - loss: 0.1485 - accuracy: 0.9441 - val_loss: 0.3713 - val_accuracy: 0.8651 - lr: 0.0010
# Epoch 23/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9467
# Epoch 00023: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 483ms/step - loss: 0.1405 - accuracy: 0.9467 - val_loss: 0.6106 - val_accuracy: 0.8287 - lr: 0.0010
# Epoch 24/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9480
# Epoch 00024: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 481ms/step - loss: 0.1372 - accuracy: 0.9480 - val_loss: 0.4058 - val_accuracy: 0.8689 - lr: 0.0010
# Epoch 25/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9532
# Epoch 00025: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 55s 477ms/step - loss: 0.1284 - accuracy: 0.9532 - val_loss: 0.4469 - val_accuracy: 0.8654 - lr: 0.0010
# Epoch 26/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9519
# Epoch 00026: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 479ms/step - loss: 0.1266 - accuracy: 0.9519 - val_loss: 0.4453 - val_accuracy: 0.8694 - lr: 0.0010
# Epoch 27/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9538
# Epoch 00027: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 484ms/step - loss: 0.1197 - accuracy: 0.9538 - val_loss: 0.5082 - val_accuracy: 0.8648 - lr: 0.0010
# Epoch 28/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9552
# Epoch 00028: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 481ms/step - loss: 0.1173 - accuracy: 0.9552 - val_loss: 0.5150 - val_accuracy: 0.8624 - lr: 0.0010
# Epoch 29/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9574
# Epoch 00029: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 57s 488ms/step - loss: 0.1090 - accuracy: 0.9574 - val_loss: 0.5461 - val_accuracy: 0.8567 - lr: 0.0010
# Epoch 30/30
# 116/116 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9598
# Epoch 00030: val_accuracy did not improve from 0.87731
# 116/116 [==============================] - 56s 484ms/step - loss: 0.1055 - accuracy: 0.9598 - val_loss: 0.6239 - val_accuracy: 0.8629 - lr: 0.0010

# %% [markdown]
# ## Load the saved model

# %%
Mustache_model = load_model("/content/gdrive/My Drive/Big Data/models mustache/Mustache.hdf5")
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
accuracy = Mustache_model.evaluate(X_test, y_test, verbose = 0)[1]
print(accuracy)
# Out:
# 0.8773072957992554
