# %%
import zipfile
import os
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from PIL import Image
from matplotlib.pyplot import imshow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model, load_model
from keras.layers.core import Dense, Dropout, Activation,Flatten
from tensorflow.keras.layers import Input, concatenate, Dense, Flatten, Activation, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LambdaCallback
from keras import optimizers
from keras.utils import np_utils
# %matplotlib inline

from google.colab import drive, files
drive.mount('/content/gdrive',force_remount = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Mounted at /content/gdrive
# Using TensorFlow backend.

# %% [markdown]
# ## Unzipping the file with the images

# %%
with zipfile.ZipFile('/content/gdrive/My Drive/Big Data/Projet/celeba-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/img/')

# %% [markdown]
# # Resize images

# %%
image = Image.open('/content/img/img_align_celeba/img_align_celeba/000001.jpg')
new_image = image.resize((128, 128))
plt.imshow(new_image)

# %% [markdown]
# # Preprocessing: devided the image into two : the mouth and the upper part of the face

# %%
attr = pd.read_csv('/content/img/list_landmarks_align_celeba.csv')
samp = pickle.load(open('/content/gdrive/My Drive/Big Data/Projet/Listes sample/Young.pkl', 'rb'))

# %%
attr = attr[['image_id', 'leftmouth_x', 'leftmouth_y', 'rightmouth_x', 'rightmouth_y']]

# %%
#select images
coord = attr.loc[attr[attr['image_id'].isin(samp) == True].index]
coord = coord.set_index('image_id')
coord.head()
# Out:
#             leftmouth_x  leftmouth_y  rightmouth_x  rightmouth_y
# image_id
# 000020.jpg           72          152           103           151
# 000040.jpg           73          152           103           152
# 000056.jpg           74          152           103           152
# 000064.jpg           71          151           106           152
# 000066.jpg           65          149           114           150

# %%
np.random.seed(1997)
aleatoire = np.random.randint(len(coord))
image = Image.open('/content/img/img_align_celeba/img_align_celeba/' + coord.index[aleatoire])
plt.imshow(image)
plt.scatter(coord['leftmouth_x'].iloc[0], coord['leftmouth_y'].iloc[aleatoire],
            c = 'r', marker = 'o')
plt.scatter(coord['rightmouth_x'].iloc[0], coord['rightmouth_y'].iloc[aleatoire],
            c = 'r', marker = 'o')

# %%
plt.imshow(image.crop((0, 0, 178, min(coord.leftmouth_y.loc[coord.index[aleatoire]],
                                      coord.rightmouth_y.loc[coord.index[aleatoire]])-10) ))

# %%
plt.imshow(image.crop((0, min(coord.leftmouth_y.loc[coord.index[aleatoire]],
                              coord.rightmouth_y.loc[coord.index[aleatoire]])-10, 178, 218)))

# %% [markdown]
# # Création de la base de données

# %%
coord.head()
# Out:
#             leftmouth_x  leftmouth_y  rightmouth_x  rightmouth_y
# image_id
# 000020.jpg           72          152           103           151
# 000040.jpg           73          152           103           152
# 000056.jpg           74          152           103           152
# 000064.jpg           71          151           106           152
# 000066.jpg           65          149           114           150

# %%
path = '/content/img/img_align_celeba/img_align_celeba/'
target = []
data_upper = np.zeros((len(samp), 64, 64, 3)) #dimension of the images
count = 0
for file in os.listdir(path):
  if file in samp :
    temp = file
    image = Image.open(path + file)
    
    separation = min(coord.leftmouth_y.loc[file],
                    coord.rightmouth_y.loc[file])-10
    image = image.crop((0, 0, 178, separation))
    image = image.resize((64, 64))
    image = np.array(image)
    data_upper[count] = image
    target.append(file)
    if count%1000 == 0 :
      print(count)
    count += 1
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000

# %%
data_under = np.zeros((len(target), 64, 64, 3)) #dimension of the images
count = 0
for file in target :
    image = Image.open(path + file)
    separation = min(coord.leftmouth_y.loc[file],
                     coord.rightmouth_y.loc[file])-10
    image = image.crop((0, separation, 178, 218))
    image = image.resize((64, 64))
    data_under[count] = np.array(image)
    if count%1000 == 0 :
      print(count)
    count += 1
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000

# %%
all_attributes = pd.read_csv('/content/img/list_attr_celeba.csv')
smiling = all_attributes[['image_id','Young']]
smiling = smiling.loc[smiling[smiling['image_id'].isin(target) == True].index]
smiling = smiling.set_index('image_id')
smiling = smiling.loc[target]
smiling.head()
# Out:
#             Young
# image_id
# 124526.jpg     -1
# 064612.jpg     -1
# 163447.jpg      1
# 025460.jpg      1
# 190788.jpg      1

# %% [markdown]
# # Creation of the train and test sets

# %%
target = np.array(smiling.Young)
target[target==-1] = 0

# %%
X_train_under, X_test_under, y_train, y_test = train_test_split(data_under, target, 
                                                                test_size = 0.2, random_state = 0)
X_train_upper, X_test_upper, y_train, y_test = train_test_split(data_upper, target, 
                                                                test_size = 0.2, random_state = 0)

# %%
plt.imshow(X_train_upper[0].astype('uint8'))

# %%
plt.imshow(X_train_under[0].astype('uint8'))

# %% [markdown]
# # Creation of the NNs

# %% [markdown]
# Here we are going to create two neural networks to process on one part the upper part of the picture and on the second part ther lower part of the picture. Both networks will then join for the last connected layer

# %%
in1 = Input(shape = (64, 64, 3,),name = 'under_input')
x1 = Conv2D(64, (3, 3), activation = 'relu')(in1)
x1 = MaxPooling2D(pool_size=(2, 2))(x1)
x1 = Conv2D(128, (3, 3), activation = 'relu')(x1)
x1 = MaxPooling2D(pool_size = (2, 2))(x1)
x1 = Dropout(0.4)(x1)
x1 = Conv2D(256, (3, 3), activation = 'relu')(x1)
x1 = MaxPooling2D(pool_size = (2, 2))(x1)
x1 = Dropout(0.4)(x1)
x1 = Conv2D(512, (3, 3), activation = 'relu')(x1)
x1 = MaxPooling2D(pool_size = (2, 2))(x1)
x1 = Flatten()(x1)
out1 = Dense(2048, activation = 'relu')(x1)

in2 = Input((64, 64, 3), name = 'upper_input')
x2 = Conv2D(64, (3, 3), activation = 'relu')(in2)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x2 = Conv2D(128, (3, 3), activation = 'relu')(x2)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x2 = Dropout(0.4)(x2)
x2 = Conv2D(256, (3, 3), activation = 'relu')(x2)
x2 = MaxPooling2D(pool_size=(2, 2))(x2)
x2 = Dropout(0.4)(x2)
x2 = Conv2D(512, (3, 3), activation = 'relu')(x2)
x2 = MaxPooling2D(pool_size = (2, 2))(x2)
x2 = Flatten()(x2)
out2 = Dense(2048, activation = 'relu')(x2)


x = concatenate([out1, out2])
x = Dense(4096, activation = 'relu')(x)
x = Dropout(0.4)(x)
out = Dense(1, activation = 'sigmoid')(x)

model_smile = Model(inputs = [in1, in2], outputs = [out])

model_smile.compile(loss = 'binary_crossentropy', optimizer = 'Adam', 
                    metrics = ['accuracy'])

# %% [markdown]
# ## callbacks to save the best model

# %%
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=1, min_lr=0.001)

# Path where we will save our model
filepath = "/content/gdrive/My Drive/Big Data/models/Young.hdf5" 
checkpoint = ModelCheckpoint(filepath, monitor = 'val_accuracy',
                             verbose = 1, save_best_only = True,
                             mode = 'max')
callbacks = [checkpoint, reduce_lr]

# %%
model_smile.fit({'under_input': X_train_under, 'upper_input': X_train_upper},
                y_train, batch_size = 128, epochs = 40, 
                validation_data=({'under_input': X_test_under, 
                                  'upper_input': X_test_upper}, y_test), 
                                    callbacks = callbacks)
# Out:
# Epoch 1/40
# 125/125 [==============================] - ETA: 0s - loss: 15.5506 - accuracy: 0.5502
# Epoch 00001: val_accuracy improved from -inf to 0.59925, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 9s 69ms/step - loss: 15.5506 - accuracy: 0.5502 - val_loss: 0.6741 - val_accuracy: 0.5993 - lr: 0.0010
# Epoch 2/40
# 125/125 [==============================] - ETA: 0s - loss: 0.6398 - accuracy: 0.6313
# Epoch 00002: val_accuracy improved from 0.59925 to 0.60950, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 8s 61ms/step - loss: 0.6398 - accuracy: 0.6313 - val_loss: 0.6417 - val_accuracy: 0.6095 - lr: 0.0010
# Epoch 3/40
# 125/125 [==============================] - ETA: 0s - loss: 0.6204 - accuracy: 0.6513
# Epoch 00003: val_accuracy improved from 0.60950 to 0.67450, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 8s 63ms/step - loss: 0.6204 - accuracy: 0.6513 - val_loss: 0.6000 - val_accuracy: 0.6745 - lr: 0.0010
# Epoch 4/40
# 125/125 [==============================] - ETA: 0s - loss: 0.6100 - accuracy: 0.6617
# Epoch 00004: val_accuracy did not improve from 0.67450
# 125/125 [==============================] - 6s 51ms/step - loss: 0.6100 - accuracy: 0.6617 - val_loss: 0.6005 - val_accuracy: 0.6720 - lr: 0.0010
# Epoch 5/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.6717
# Epoch 00005: val_accuracy improved from 0.67450 to 0.68775, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 9s 75ms/step - loss: 0.5984 - accuracy: 0.6717 - val_loss: 0.5867 - val_accuracy: 0.6877 - lr: 0.0010
# Epoch 6/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5911 - accuracy: 0.6769
# Epoch 00006: val_accuracy improved from 0.68775 to 0.68850, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 8s 63ms/step - loss: 0.5911 - accuracy: 0.6769 - val_loss: 0.5966 - val_accuracy: 0.6885 - lr: 0.0010
# Epoch 7/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5842 - accuracy: 0.6841
# Epoch 00007: val_accuracy improved from 0.68850 to 0.69600, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 7s 58ms/step - loss: 0.5842 - accuracy: 0.6841 - val_loss: 0.5750 - val_accuracy: 0.6960 - lr: 0.0010
# Epoch 8/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5702 - accuracy: 0.6942
# Epoch 00008: val_accuracy did not improve from 0.69600
# 125/125 [==============================] - 6s 50ms/step - loss: 0.5702 - accuracy: 0.6942 - val_loss: 0.5731 - val_accuracy: 0.6905 - lr: 0.0010
# Epoch 9/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5608 - accuracy: 0.6994
# Epoch 00009: val_accuracy did not improve from 0.69600
# 125/125 [==============================] - 6s 50ms/step - loss: 0.5608 - accuracy: 0.6994 - val_loss: 0.5920 - val_accuracy: 0.6793 - lr: 0.0010
# Epoch 10/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5495 - accuracy: 0.7079
# Epoch 00010: val_accuracy improved from 0.69600 to 0.71950, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 9s 76ms/step - loss: 0.5495 - accuracy: 0.7079 - val_loss: 0.5508 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 11/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5491 - accuracy: 0.7106
# Epoch 00011: val_accuracy improved from 0.71950 to 0.72375, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 8s 61ms/step - loss: 0.5491 - accuracy: 0.7106 - val_loss: 0.5690 - val_accuracy: 0.7237 - lr: 0.0010
# Epoch 12/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.7173
# Epoch 00012: val_accuracy improved from 0.72375 to 0.72825, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 8s 64ms/step - loss: 0.5392 - accuracy: 0.7173 - val_loss: 0.5417 - val_accuracy: 0.7283 - lr: 0.0010
# Epoch 13/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5386 - accuracy: 0.7226
# Epoch 00013: val_accuracy did not improve from 0.72825
# 125/125 [==============================] - 6s 50ms/step - loss: 0.5386 - accuracy: 0.7226 - val_loss: 0.5713 - val_accuracy: 0.7072 - lr: 0.0010
# Epoch 14/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5321 - accuracy: 0.7272
# Epoch 00014: val_accuracy improved from 0.72825 to 0.72950, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 7s 60ms/step - loss: 0.5321 - accuracy: 0.7272 - val_loss: 0.5276 - val_accuracy: 0.7295 - lr: 0.0010
# Epoch 15/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5207 - accuracy: 0.7364
# Epoch 00015: val_accuracy improved from 0.72950 to 0.73875, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 7s 60ms/step - loss: 0.5207 - accuracy: 0.7364 - val_loss: 0.5527 - val_accuracy: 0.7387 - lr: 0.0010
# Epoch 16/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5173 - accuracy: 0.7366
# Epoch 00016: val_accuracy did not improve from 0.73875
# 125/125 [==============================] - 6s 50ms/step - loss: 0.5173 - accuracy: 0.7366 - val_loss: 0.5434 - val_accuracy: 0.7352 - lr: 0.0010
# Epoch 17/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5151 - accuracy: 0.7352
# Epoch 00017: val_accuracy improved from 0.73875 to 0.74700, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 10s 82ms/step - loss: 0.5151 - accuracy: 0.7352 - val_loss: 0.5192 - val_accuracy: 0.7470 - lr: 0.0010
# Epoch 18/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5102 - accuracy: 0.7433
# Epoch 00018: val_accuracy did not improve from 0.74700
# 125/125 [==============================] - 6s 49ms/step - loss: 0.5102 - accuracy: 0.7433 - val_loss: 0.5146 - val_accuracy: 0.7402 - lr: 0.0010
# Epoch 19/40
# 125/125 [==============================] - ETA: 0s - loss: 0.5023 - accuracy: 0.7483
# Epoch 00019: val_accuracy did not improve from 0.74700
# 125/125 [==============================] - 6s 51ms/step - loss: 0.5023 - accuracy: 0.7483 - val_loss: 0.5129 - val_accuracy: 0.7450 - lr: 0.0010
# Epoch 20/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4983 - accuracy: 0.7514
# Epoch 00020: val_accuracy improved from 0.74700 to 0.74825, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 11s 88ms/step - loss: 0.4983 - accuracy: 0.7514 - val_loss: 0.5196 - val_accuracy: 0.7483 - lr: 0.0010
# Epoch 21/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.7495
# Epoch 00021: val_accuracy improved from 0.74825 to 0.75100, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 8s 61ms/step - loss: 0.4964 - accuracy: 0.7495 - val_loss: 0.5099 - val_accuracy: 0.7510 - lr: 0.0010
# Epoch 22/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4884 - accuracy: 0.7577
# Epoch 00022: val_accuracy did not improve from 0.75100
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4884 - accuracy: 0.7577 - val_loss: 0.5225 - val_accuracy: 0.7418 - lr: 0.0010
# Epoch 23/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4882 - accuracy: 0.7588
# Epoch 00023: val_accuracy improved from 0.75100 to 0.75725, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 10s 79ms/step - loss: 0.4882 - accuracy: 0.7588 - val_loss: 0.5046 - val_accuracy: 0.7573 - lr: 0.0010
# Epoch 24/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4889 - accuracy: 0.7555
# Epoch 00024: val_accuracy did not improve from 0.75725
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4889 - accuracy: 0.7555 - val_loss: 0.5222 - val_accuracy: 0.7440 - lr: 0.0010
# Epoch 25/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4783 - accuracy: 0.7683
# Epoch 00025: val_accuracy improved from 0.75725 to 0.76025, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 9s 69ms/step - loss: 0.4783 - accuracy: 0.7683 - val_loss: 0.4996 - val_accuracy: 0.7602 - lr: 0.0010
# Epoch 26/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4683 - accuracy: 0.7695
# Epoch 00026: val_accuracy did not improve from 0.76025
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4683 - accuracy: 0.7695 - val_loss: 0.5075 - val_accuracy: 0.7387 - lr: 0.0010
# Epoch 27/40
# 124/125 [============================>.] - ETA: 0s - loss: 0.4738 - accuracy: 0.7732
# Epoch 00027: val_accuracy did not improve from 0.76025
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4735 - accuracy: 0.7734 - val_loss: 0.5191 - val_accuracy: 0.7563 - lr: 0.0010
# Epoch 28/40
# 124/125 [============================>.] - ETA: 0s - loss: 0.4601 - accuracy: 0.7770
# Epoch 00028: val_accuracy did not improve from 0.76025
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4598 - accuracy: 0.7773 - val_loss: 0.5136 - val_accuracy: 0.7358 - lr: 0.0010
# Epoch 29/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4588 - accuracy: 0.7759
# Epoch 00029: val_accuracy did not improve from 0.76025
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4588 - accuracy: 0.7759 - val_loss: 0.5207 - val_accuracy: 0.7380 - lr: 0.0010
# Epoch 30/40
# 124/125 [============================>.] - ETA: 0s - loss: 0.4603 - accuracy: 0.7791
# Epoch 00030: val_accuracy did not improve from 0.76025
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4601 - accuracy: 0.7793 - val_loss: 0.4904 - val_accuracy: 0.7590 - lr: 0.0010
# Epoch 31/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.7839
# Epoch 00031: val_accuracy improved from 0.76025 to 0.76050, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 9s 70ms/step - loss: 0.4456 - accuracy: 0.7839 - val_loss: 0.5043 - val_accuracy: 0.7605 - lr: 0.0010
# Epoch 32/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4423 - accuracy: 0.7880
# Epoch 00032: val_accuracy did not improve from 0.76050
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4423 - accuracy: 0.7880 - val_loss: 0.5032 - val_accuracy: 0.7552 - lr: 0.0010
# Epoch 33/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4476 - accuracy: 0.7859
# Epoch 00033: val_accuracy did not improve from 0.76050
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4476 - accuracy: 0.7859 - val_loss: 0.5242 - val_accuracy: 0.7540 - lr: 0.0010
# Epoch 34/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4367 - accuracy: 0.7941
# Epoch 00034: val_accuracy did not improve from 0.76050
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4367 - accuracy: 0.7941 - val_loss: 0.4906 - val_accuracy: 0.7590 - lr: 0.0010
# Epoch 35/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4260 - accuracy: 0.7979
# Epoch 00035: val_accuracy improved from 0.76050 to 0.76500, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 9s 69ms/step - loss: 0.4260 - accuracy: 0.7979 - val_loss: 0.4988 - val_accuracy: 0.7650 - lr: 0.0010
# Epoch 36/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4313 - accuracy: 0.7975
# Epoch 00036: val_accuracy improved from 0.76500 to 0.76775, saving model to /content/gdrive/My Drive/Big Data/models/Young.hdf5
# 125/125 [==============================] - 8s 61ms/step - loss: 0.4313 - accuracy: 0.7975 - val_loss: 0.4876 - val_accuracy: 0.7678 - lr: 0.0010
# Epoch 37/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4284 - accuracy: 0.8002
# Epoch 00037: val_accuracy did not improve from 0.76775
# 125/125 [==============================] - 6s 51ms/step - loss: 0.4284 - accuracy: 0.8002 - val_loss: 0.5280 - val_accuracy: 0.7310 - lr: 0.0010
# Epoch 38/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.7983
# Epoch 00038: val_accuracy did not improve from 0.76775
# 125/125 [==============================] - 7s 53ms/step - loss: 0.4269 - accuracy: 0.7983 - val_loss: 0.5022 - val_accuracy: 0.7542 - lr: 0.0010
# Epoch 39/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8040
# Epoch 00039: val_accuracy did not improve from 0.76775
# 125/125 [==============================] - 6s 49ms/step - loss: 0.4209 - accuracy: 0.8040 - val_loss: 0.5001 - val_accuracy: 0.7555 - lr: 0.0010
# Epoch 40/40
# 125/125 [==============================] - ETA: 0s - loss: 0.4162 - accuracy: 0.8029
# Epoch 00040: val_accuracy did not improve from 0.76775
# 125/125 [==============================] - 6s 50ms/step - loss: 0.4162 - accuracy: 0.8029 - val_loss: 0.5007 - val_accuracy: 0.7607 - lr: 0.0010

# %% [markdown]
# ## Load the saved model

# %%
#modelLoaded = load_model("/content/gdrive/My Drive/Big Data/models/BestModelMale.hdf5")

# %%
pred = model_smile.predict({'under_input': X_test_under, 
                            'upper_input': X_test_upper}, verbose = 1) #get all predictions
# Out:
# 125/125 [==============================] - 1s 6ms/step

# %% [markdown]
# ## Test the predictions with the previous exemple when we put scatters on the mouth of the person on the picture

# %%
image = Image.open('/content/img/img_align_celeba/img_align_celeba/' + coord.index[aleatoire])
plt.imshow(image)

# %%
upper_image = np.zeros((1, 64, 64, 3))
temp = np.array(image.crop((0, 0, 178, min(coord.leftmouth_y.loc[coord.index[aleatoire]],
                                      coord.rightmouth_y.loc[coord.index[aleatoire]])-10) ).resize((64, 64)))
upper_image[0] = temp

# %%
under_image = np.zeros((1, 64, 64, 3))

temp = np.array(image.crop((0, min(coord.leftmouth_y.loc[coord.index[aleatoire]],
                              coord.rightmouth_y.loc[coord.index[aleatoire]])-10, 178, 218)).resize((64, 64)))

under_image[0] = temp

# %%
X_test_under.shape
# Out:
# (4000, 64, 64, 3)

# %%
pred_test = model_smile.predict({'under_input': under_image, 
                                 'upper_input': upper_image}, verbose=1) #get the prediction of this image


face = np.random.choice(len(y_test), 1)[0]
plt.imshow(image)
plt.show()
print_sex = lambda x: "young" if x >= 0.5 else "old"                        #Function that prints the predicted sex
print("This person is : ", print_sex(pred_test[0]))
# Out:
# 1/1 [==============================] - 0s 1ms/step
# This person is :  old
